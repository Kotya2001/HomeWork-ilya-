# %%
# !pip3 install openpyxl
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\белозеров илья\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.
# ...
# Using legacy setup.py install for et-xmlfile, since package 'wheel' is not installed.
# ...
#     Running setup.py install for et-xmlfile: started
#     Running setup.py install for et-xmlfile: finished with status 'done'
# ...

# %%
import openpyxl
import pandas as pd
import matplotlib

rows = sheets.max_row
cols = sheets.max_column
cat = [sheets.cell(row=i, column=1) for i in range(4, rows+1) if sheets.cell(row=i, column=1).value[2] != ' '\
      and 'C-0' not in sheets.cell(row=i, column=1).value and sheets.cell(row=i, column=1).value.isupper() == False
      and '0' not in sheets.cell(row=i, column=1).value]
cats = [sheets.cell(row=i, column=1).value.strip() for i in range(4, rows+1) if sheets.cell(row=i, column=1).value[2] != ' '\
      and 'C-0' not in sheets.cell(row=i, column=1).value and sheets.cell(row=i, column=1).value.isupper() == False
      and '0' not in sheets.cell(row=i, column=1).value]

prices = []
for c in range(len(cat)-1):
    price = [float(sheets.cell(row=j, column=3).value) for j in range(cat[c].row, cat[c+1].row+1 ) if sheets.cell(row=j, column=3).value 
 is not None]
    prices.append(price)
    prices.append([float(sheets.cell(row=elem, column=3).value) for elem in range(cat[80].row, 38197) 
                   if sheets.cell(row=elem, column=3).value is not None])

    

for n in range(81):
    data = {cats[n] : prices[n]}
    Data = pd.DataFrame(data)
    Data.plot.box()
# Out:
# c:\users\белозеров илья\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
